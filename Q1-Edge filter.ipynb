# %%
import cv2 as cv

# %%
img=cv.imread('1-1.webp')
cv.imshow('pic',img)
# Out:
# ...
# QObject::moveToThread: Current thread (0x1c587e0) is not the object's thread (0x1739eb0).
# Cannot move to target thread (0x1c587e0)
#
# QObject::moveToThread: Current thread (0x1c587e0) is not the object's thread (0x1739eb0).
# Cannot move to target thread (0x1c587e0)
#
# QObject::moveToThread: Current thread (0x1c587e0) is not the object's thread (0x1739eb0).
# Cannot move to target thread (0x1c587e0)
#
# QObject::moveToThread: Current thread (0x1c587e0) is not the object's thread (0x1739eb0).
# Cannot move to target thread (0x1c587e0)
#
# QObject::moveToThread: Current thread (0x1c587e0) is not the object's thread (0x1739eb0).
# Cannot move to target thread (0x1c587e0)
#
# QObject::moveToThread: Current thread (0x1c587e0) is not the object's thread (0x1739eb0).
# Cannot move to target thread (0x1c587e0)
#
# QObject::moveToThread: Current thread (0x1c587e0) is not the object's thread (0x1739eb0).
# Cannot move to target thread (0x1c587e0)
#
# ...
